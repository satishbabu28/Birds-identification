# %%
from keras.models import load_model
import numpy as np
import cv2
model= load_model('mybirds.h5')

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from skimage.transform import resize
def detect(frame):
    try:
        img = resize(frame,(128,128))
        img=np.expand_dims(img,axis=0)
        if(np.max(img)>1):
            img= img/255.0
        prediction = model.predict(img)
        print(prediction)
        prediction_class= model.predict_classes(img)
        print(prediction_class)
               
    except AttributeError:
        print("Shape not found")

# %%
from matplotlib.pyplot import *

# %%
frame=cv2.imread(r'C:\Users\chinni\Desktop\AI\project\testdata\001.Black_footed_Albatross\Black_Footed_Albatross_0024_796089.jpg')#path of image 
imshow(frame)
data= detect(frame)
# Out:
# [[9.9999225e-01 1.9327961e-06 5.8845708e-06]]
# [0]

# %%
frame=cv2.imread(r'C:\Users\chinni\Desktop\AI\project\testdata\004.Groove_billed_Ani\Groove_billed_Ani_0012_2410652192.jpg')#path of image 
imshow(frame)
data= detect(frame)
# Out:
# [[5.5615834e-05 9.9800426e-01 1.9401867e-03]]
# [1]

# %%
frame=cv2.imread(r'C:\Users\chinni\Desktop\AI\project\testdata\009.Brewer_Blackbird\Brewer_Blackbird_0001_13030268.jpg')#path of image 
imshow(frame)
data= detect(frame)
# Out:
# [[4.7713943e-06 2.4163583e-06 9.9999285e-01]]
# [2]
